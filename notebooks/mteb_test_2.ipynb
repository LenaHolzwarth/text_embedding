# %%
import mteb 
from sentence_transformers import SentenceTransformer 
import torch
import gc

# %%
"This".split()
# Out:
# ['This']

# %%
raise Exception("This is exceptional!")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 raise Exception("This is exceptional!")
#
# Exception: This is exceptional!

# %%
d = {"entry_1": "A", "entry_2": "B"}
"entry_2" in d
# Out:
# True

# %%
# define model name strings for ease of use
komninos = "average_word_embeddings_komninos"
glove = "sentence-transformers/average_word_embeddings_glove.6B.300d"

# %%
tasks = mteb.get_benchmark("MTEB(eng)")
tasks.tasks
# Out:
# MTEBTasks(AmazonCounterfactualClassification(name='AmazonCounterfactualClassification', languages=['eng']), AmazonPolarityClassification(name='AmazonPolarityClassification', languages=['eng']), AmazonReviewsClassification(name='AmazonReviewsClassification', languages=['eng']), ArguAna(name='ArguAna', languages=['eng']), ArxivClusteringP2P(name='ArxivClusteringP2P', languages=['eng']), ArxivClusteringS2S(name='ArxivClusteringS2S', languages=['eng']), AskUbuntuDupQuestions(name='AskUbuntuDupQuestions', languages=['eng']), BiossesSTS(name='BIOSSES', languages=['eng']), Banking77Classification(name='Banking77Classification', languages=['eng']), BiorxivClusteringP2P(name='BiorxivClusteringP2P', languages=['eng']), BiorxivClusteringS2S(name='BiorxivClusteringS2S', languages=['eng']), CQADupstackAndroidRetrieval(name='CQADupstackAndroidRetrieval', languages=['eng']), CQADupstackEnglishRetrieval(name='CQADupstackEnglishRetrieval', languages=['eng']), CQADupstackGamingRetrieval(name='CQADupst
# ...

# %%
tasks = mteb.get_benchmark("MTEB(eng)")
tasks = mteb.get_tasks(tasks = ["ClimateFEVER"])
isinstance(tasks, mteb.overview.MTEBTasks)
# Out:
# True

# %%
mteb.get_tasks(task_types=["Classification"])
# Out:
# MTEBTasks(AJGT(name='AJGT', languages=['ara']), HotelReviewSentimentClassification(name='HotelReviewSentimentClassification', languages=['ara']), OnlineStoreReviewSentimentClassification(name='OnlineStoreReviewSentimentClassification', languages=['ara']), RestaurantReviewSentimentClassification(name='RestaurantReviewSentimentClassification', languages=['ara']), TweetEmotionClassification(name='TweetEmotionClassification', languages=['ara']), TweetSarcasmClassification(name='TweetSarcasmClassification', languages=['ara']), BengaliDocumentClassification(name='BengaliDocumentClassification', languages=['ben']), BengaliHateSpeechClassification(name='BengaliHateSpeechClassification', languages=['ben']), BengaliSentimentAnalysis(name='BengaliSentimentAnalysis', languages=['ben']), BulgarianStoreReviewSentimentClassfication(name='BulgarianStoreReviewSentimentClassfication', languages=['bul']), CSFDCZMovieReviewSentimentClassification(name='CSFDCZMovieReviewSentimentClassification', language
# ...

# %%
type(mteb.get_tasks(tasks=["ArguAna"]))
# Out:
# mteb.overview.MTEBTasks

# %%
model = mteb.get_model(komninos)
tasks = mteb.get_tasks(tasks = ["AmazonPolarityClassification", "ArguAna"])
for task in tasks:
    print(task)
    print(mteb.overview.MTEBTasks([task]))
    evaluation = mteb.MTEB(tasks=[task])
    results = evaluation.run(model)
# Out:
# AmazonPolarityClassification(name='AmazonPolarityClassification', languages=['eng'])
# MTEBTasks(AmazonPolarityClassification(name='AmazonPolarityClassification', languages=['eng']),)
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Classification
#     - AmazonPolarityClassification, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ArguAna(name='ArguAna', languages=['eng'])
# MTEBTasks(ArguAna(name='ArguAna', languages=['eng']),)
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Retrieval
#     - ArguAna, s2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ...

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
# run single task
model = mteb.get_model(glove)
tasks = mteb.get_tasks(tasks = ["ClimateFEVER"])

evaluation_single = mteb.MTEB(tasks=tasks)
# default batch size is 128, need to reduce for ClimateFEVER
results_single = evaluation_single.run(model, encode_kwargs = {'batch_size': 64})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Retrieval
#     - ClimateFEVER, s2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# WARNING:mteb.evaluation.evaluators.RetrievalEvaluator:Queries will not be truncated. This could lead to memory issues. In that case please lower the batch_size.
# ...
# Batches:   0%|          | 0/782 [00:00<?, ?it/s]
# ...

# %%
results_single[0].scores
# Out:
# {'test': [{'accuracy': 0.6780844155844156,
#    'f1': 0.6774104930303826,
#    'f1_weighted': 0.6774104930303826,
#    'scores_per_experiment': [{'accuracy': 0.6824675324675324,
#      'f1': 0.6817043090519325,
#      'f1_weighted': 0.6817043090519326},
#     {'accuracy': 0.6701298701298701,
#      'f1': 0.6706749107383029,
#      'f1_weighted': 0.670674910738303},
#     {'accuracy': 0.6857142857142857,
#      'f1': 0.6863922204318087,
#      'f1_weighted': 0.6863922204318087},
#     {'accuracy': 0.6844155844155844,
#      'f1': 0.6848342399527514,
#      'f1_weighted': 0.6848342399527515},
#     {'accuracy': 0.6792207792207792,
#      'f1': 0.678729213131745,
#      'f1_weighted': 0.6787292131317448},
#     {'accuracy': 0.6795454545454546,
#      'f1': 0.6771085974907199,
#      'f1_weighted': 0.67710859749072},
#     {'accuracy': 0.6795454545454546,
#      'f1': 0.6765568751574049,
#      'f1_weighted': 0.6765568751574048},
#     {'accuracy': 0.6724025974025974,
# ...

# %%
# run entire english MTEB 
model = mteb.get_model(glove)
tasks = mteb.get_benchmark("MTEB(eng)")

evaluation_full = mteb.MTEB(tasks=tasks)
results_full = evaluation_full.run(model)
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# STS
#     - BIOSSES, s2s
#     - SICK-R, s2s
#     - STS12, s2s
#     - STS13, s2s
#     - STS14, s2s
#     - STS15, s2s
#     - STS16, s2s
#     - STS17, s2s, multilingual 8 / 11 Subsets
#     - STS22, p2p, multilingual 5 / 18 Subsets
#     - STSBenchmark, s2s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Summarization
#     - SummEval, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Clustering
#     - ArxivClusteringP2P, p2p
#     - ArxivClusteringS2S, s2s
#     - BiorxivClusteringP2P, p2p
#     - BiorxivClusteringS2S, s2s
#     - MedrxivClusteringP2P, p2p
#     - MedrxivClusteringS2S, s2s
#     - RedditClustering, s2s
#     - RedditClusteringP2P, p2p
# ...
