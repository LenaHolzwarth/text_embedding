# %% [markdown]
# Evaluate different vocab functions and what types of words they select

# %% [markdown]
# #### 1. compare self-made get_vocab with sklearn tfidf version

# %%
import datasets
import json
from numpyencoder import NumpyEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from mteb.evaluation.evaluators.utils import get_vocab

# %%
# load dataset
arxiv_data = datasets.load_dataset("mteb/arxiv-clustering-p2p", revision="a122ad7f3f0291bf49cc6f4d32aa80929df69d5d")["test"]
biorxiv_data = datasets.load_dataset("mteb/biorxiv-clustering-p2p", revision="f5dbc242e11dd8e24def4c4268607a49e02946dc")["test"]

# %%
arxiv_sents = [x for split in arxiv_data for x in split["sentences"]]
biorxiv_sents = [split["sentences"] for split in biorxiv_data]

# %%
# compute vocab with get_vocab
vocab_selfmade = get_vocab(biorxiv_sents)
# Out:
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: None
# vocab of lenght 168265 (313%) starting with ['pmce', 'efficient', 'inference', 'of', 'expressive', 'models', 'cancer', 'evolution', 'with', 'high']

# %%
# compute vocab with sklearn 
# initialize the model
vectorizer = TfidfVectorizer()
# fit on data
vectorizer_fit = vectorizer.fit(biorxiv_sents)

vocab_sklearn = vectorizer_fit.vocabulary_

# %%
len(vocab_sklearn)
# Out:
# 168265

# %%
vocab_sklearn_lower = [word for word in sorted(list(vocab_sklearn.keys())) if word.islower()]

# %%
len(vocab_sklearn_lower)
# Out:
# 164699

# %%
vocab_selfmade = get_vocab(arxiv_sents)
# Out:
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab of lenght 331735 starting with ['0000011d', '000026yorke', '00007h', '0001035v2', '00015t', '00019d', '0002bx', '0002d', '0002ev', '0002msun']

# %%
# compute vocab with sklearn 
# initialize the model
vectorizer = TfidfVectorizer()
# fit on data
vectorizer_fit = vectorizer.fit(arxiv_sents)

vocab_sklearn = vectorizer_fit.vocabulary_

len(vocab_sklearn)
# Out:
# 354026

# %% [markdown]
# ### 2. Compare vocabs for different settings of get_vocab

# %% [markdown]
# #### a) vary max_features and ngram_range
# max_features ignores infrequent words in the corpus (independent of their distribution)
#
# range: [1000, 2000, 5000, 10000, unlimited]

# %%
ngram_range_ = [(1,1), (1,2), (2,2)]
max_df_ = [1.0]
min_df_ = [1]
max_features_ = [1000, 2000, 5000, 10000, None]

# %%
# Arxiv data
dataset_name = "arxiv"
for ngram_range in ngram_range_:
    for max_df in max_df_:
        for min_df in min_df_:
            for max_features in max_features_:
                vocab = get_vocab(arxiv_sents, 
                                  ngram_range = ngram_range,
                                  max_df = max_df,
                                  min_df = min_df,
                                  max_features = max_features)
                
                with open(f"../MTEB/vocabs/{dataset_name}/ngram_{ngram_range[0]}_{ngram_range[1]}_maxdf_{int(max_df)}-{int(round(max_df%1, 2)*10)}_mindf_{int(min_df)}-{int(round(min_df%1, 2)*10)}_maxfeatures_{max_features}.json", "w") as fp:
                    json.dump(vocab , fp, indent = 4, ensure_ascii=False, cls=NumpyEncoder)
# Out:
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 1000
# vocab of lenght 1000 starting with ['10', '100', '12', '20', '2d', '3d', '_2', 'able', 'about', 'above']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 2000
# vocab of lenght 2000 starting with ['10', '100', '11', '12', '13', '14', '15', '16', '18', '19']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 5000
# vocab of lenght 5000 starting with ['000', '001', '01', '02', '03', '04', '05', '06', '07', '08']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 10000
# vocab of lenght 10000 starting with ['00', '000', '0001', '001', '005', '01', '02', '03', '04', '05']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: None
# vocab of lenght 354026 starting with ['00', '000', '0000', '000000015', '0000001', '00000014', '00000017', '0000002', '00000020', '0000004']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 1000
# vocab of lenght 1000 starting with ['10', '2d', '3d', '_2', 'able', 'able to', 'about', 'above', 'account', 'accuracy']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 2000
# vocab of lenght 2000 starting with ['10', '100', '11', '12', '13', '15', '19', '20', '2d', '30']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 5000
# vocab of lenght 5000 starting with ['000', '10', '100', '11', '12', '13', '14', '15', '16', '17']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 10000
# vocab of lenght 10000 starting with ['000', '001', '01', '02', '03', '04', '05', '06', '08', '10']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: None
# vocab of lenght 10300537 starting with ['00', '00 00', '00 000', '00 00pm', '00 00ut', '00 01', '00 01059', '00 02', '00 029', '00 03']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 1000
# vocab of lenght 1000 starting with ['ability to', 'able to', 'about the', 'absence of', 'according to', 'account for', 'accuracy of', 'across the', 'addition to', 'addition we']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 2000
# vocab of lenght 2000 starting with ['ab initio', 'ability to', 'able to', 'about the', 'above the', 'absence of', 'access to', 'according to', 'account for', 'account the']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 5000
# vocab of lenght 5000 starting with ['10 10', '10 and', 'ab initio', 'ability of', 'ability to', 'able to', 'about the', 'above the', 'absence of', 'abundance of']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 10000
# vocab of lenght 10000 starting with ['10 10', '10 11', '10 12', '10 14', '10 15', '10 20', '10 and', '10 cm', '10 gev', '10 kev']
# get_vocab called!
# input: <class 'list'> of length 732723
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: None
# vocab of lenght 9946511 starting with ['00 00', '00 000', '00 00pm', '00 00ut', '00 01', '00 01059', '00 02', '00 029', '00 03', '00 04']

# %%
# Biorxiv data
dataset_name = "biorxiv"
for ngram_range in ngram_range_:
    for max_df in max_df_:
        for min_df in min_df_:
            for max_features in max_features_:
                vocab = get_vocab(biorxiv_sents, 
                                  ngram_range = ngram_range,
                                  max_df = max_df,
                                  min_df = min_df,
                                  max_features = max_features)
                
                with open(f"../MTEB/vocabs/{dataset_name}/ngram_{ngram_range[0]}_{ngram_range[1]}_maxdf_{int(max_df)}-{int(round(max_df%1, 2)*10)}_mindf_{int(min_df)}-{int(round(min_df%1, 2)*10)}_maxfeatures_{max_features}.json", "w") as fp:
                    json.dump(vocab , fp, indent = 4, ensure_ascii=False, cls=NumpyEncoder)
# Out:
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 1000
# vocab of lenght 1000 starting with ['10', '12', '15', '19', '20', '3d', 'ability', 'able', 'about', 'absence']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 2000
# vocab of lenght 2000 starting with ['000', '10', '100', '11', '12', '13', '14', '15', '16', '17']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 5000
# vocab of lenght 5000 starting with ['000', '001', '01', '05', '10', '100', '1000', '11', '12', '13']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: 10000
# vocab of lenght 10000 starting with ['00', '000', '0001', '001', '01', '02', '03', '04', '05', '06']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 1),
# max_df: 1.0,
# min_df: 1,
# max_features: None
# vocab of lenght 168265 starting with ['00', '000', '0000', '000001', '00001', '000014', '00002', '000029', '000039', '00004']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 1000
# vocab of lenght 1000 starting with ['10', '19', '3d', 'ability', 'ability to', 'able', 'able to', 'about', 'absence', 'abundance']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 2000
# vocab of lenght 2000 starting with ['000', '10', '100', '11', '12', '13', '14', '15', '16', '18']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 5000
# vocab of lenght 5000 starting with ['000', '01', '05', '10', '100', '11', '12', '13', '14', '15']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 10000
# vocab of lenght 10000 starting with ['000', '001', '01', '05', '10', '100', '1000', '11', '12', '13']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (1, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: None
# vocab of lenght 3274615 starting with ['00', '00 00', '00 001', '00 00h', '00 01', '00 013', '00 02', '00 04', '00 047', '00 05']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 1000
# vocab of lenght 1000 starting with ['200 height', 'ability of', 'ability to', 'able to', 'about the', 'absence of', 'abundance of', 'accompanied by', 'according to', 'account for']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 2000
# vocab of lenght 2000 starting with ['16s rrna', '19 pandemic', '19 patients', '200 height', 'ability of', 'ability to', 'able to', 'about the', 'absence of', 'abstract o_fig']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 5000
# vocab of lenght 5000 starting with ['16s rrna', '19 and', '19 pandemic', '19 patients', '200 height', '2019 covid', '24 hours', '50 of', '95 ci', 'ability of']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: 10000
# vocab of lenght 10000 starting with ['10 and', '10 fold', '10 of', '12 and', '16s rrna', '19 and', '19 disease', '19 pandemic', '19 patients', '20 of']
# get_vocab called!
# input: <class 'list'> of length 53787
# vocab settings:
# ngram_range: (2, 2),
# max_df: 1.0,
# min_df: 1,
# max_features: None
# vocab of lenght 3106350 starting with ['00 00', '00 001', '00 00h', '00 01', '00 013', '00 02', '00 04', '00 047', '00 05', '00 06']
