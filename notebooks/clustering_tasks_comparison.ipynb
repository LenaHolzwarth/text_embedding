# %% [markdown]
# ### Compare MTEB Clustering to MTEB ClusteringFast

# %%
import mteb
import src

# %%
# set up model
glove = "sentence-transformers/average_word_embeddings_glove.6B.300d"
model = mteb.get_model(glove)

# directory for results
results_folder = "../MTEB/clustering_comparison"

# %% [markdown]
# #### Arxiv

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["ArxivClusteringP2P"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - ArxivClusteringP2P, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Dataset 'ArxivClusteringP2P' is superseeded by 'ArXivHierarchicalClusteringP2P', you might consider using the newer version of the dataset.
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 31
#     })
# })
# number of samples: 732723
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 31
#     })
# })
# number of samples: 732723
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClustering called
# <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
# Clustering:   0%|          | 0/31 [00:00<?, ?it/s]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:   3%|▎         | 1/31 [00:07<03:43,  7.46s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:   6%|▋         | 2/31 [00:14<03:35,  7.42s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  10%|▉         | 3/31 [00:21<03:22,  7.22s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  13%|█▎        | 4/31 [00:28<03:06,  6.92s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  16%|█▌        | 5/31 [00:34<02:57,  6.83s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  19%|█▉        | 6/31 [00:41<02:48,  6.74s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  23%|██▎       | 7/31 [00:48<02:40,  6.70s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  26%|██▌       | 8/31 [00:54<02:35,  6.75s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  29%|██▉       | 9/31 [01:01<02:27,  6.70s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  32%|███▏      | 10/31 [01:08<02:19,  6.65s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  35%|███▌      | 11/31 [01:15<02:16,  6.81s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  39%|███▊      | 12/31 [01:22<02:10,  6.85s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  42%|████▏     | 13/31 [01:29<02:04,  6.93s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  45%|████▌     | 14/31 [01:36<01:58,  6.99s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  48%|████▊     | 15/31 [01:43<01:51,  6.97s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  52%|█████▏    | 16/31 [01:50<01:45,  7.02s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  55%|█████▍    | 17/31 [01:57<01:39,  7.08s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  58%|█████▊    | 18/31 [02:04<01:32,  7.12s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  61%|██████▏   | 19/31 [02:12<01:25,  7.14s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  65%|██████▍   | 20/31 [02:19<01:18,  7.10s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  68%|██████▊   | 21/31 [02:26<01:12,  7.29s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  71%|███████   | 22/31 [02:28<00:48,  5.44s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  74%|███████▍  | 23/31 [02:33<00:43,  5.43s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  77%|███████▋  | 24/31 [02:40<00:41,  5.99s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  81%|████████  | 25/31 [02:48<00:38,  6.47s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  84%|████████▍ | 26/31 [02:50<00:26,  5.26s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  87%|████████▋ | 27/31 [02:57<00:23,  5.79s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  90%|█████████ | 28/31 [03:06<00:20,  6.69s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  94%|█████████▎| 29/31 [03:13<00:13,  6.70s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  97%|█████████▋| 30/31 [03:19<00:06,  6.51s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering: 100%|██████████| 31/31 [03:25<00:00,  6.62s/it]

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["ArXivHierarchicalClusteringS2S"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - ArXivHierarchicalClusteringS2S, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 31
#     })
# })
# number of samples: 732723
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['labels', 'sentences'],
#         num_rows: 2048
#     })
# })
# number of samples: 2997
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClusteringFast called
# len(dataset['sentences']): 2048
# number of samples in downsampled dataset: 121
# evaluate_clustering_bootstrapped() called
# 10 repetitions of sampling 16384 samples

# %% [markdown]
# #### Biorxiv

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["BiorxivClusteringP2P"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - BiorxivClusteringP2P, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Dataset 'BiorxivClusteringP2P' is superseeded by 'BiorxivClusteringP2P.v2', you might consider using the newer version of the dataset.
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 75000
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 75000
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClustering called
# <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
# Clustering:   0%|          | 0/10 [00:00<?, ?it/s]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# /opt/anaconda3/envs/hertie/lib/python3.12/site-packages/threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# Clustering:  10%|█         | 1/10 [00:04<00:42,  4.70s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  20%|██        | 2/10 [00:08<00:35,  4.44s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  30%|███       | 3/10 [00:13<00:30,  4.36s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  40%|████      | 4/10 [00:17<00:26,  4.47s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  50%|█████     | 5/10 [00:22<00:23,  4.66s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  60%|██████    | 6/10 [00:25<00:15,  3.82s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  70%|███████   | 7/10 [00:27<00:10,  3.35s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  80%|████████  | 8/10 [00:29<00:06,  3.04s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  90%|█████████ | 9/10 [00:32<00:02,  2.81s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering: 100%|██████████| 10/10 [00:34<00:00,  3.47s/it]

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["BiorxivClusteringP2P.v2"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - BiorxivClusteringP2P.v2, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 53787
#     })
# })
# number of samples: 53787
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 53787
#     })
# })
# number of samples: 53787
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClusteringFast called
# len(dataset['sentences']): 53787
# number of samples in downsampled dataset: 2151
# evaluate_clustering_bootstrapped() called
# 10 repetitions of sampling 16384 samples

# %% [markdown]
# #### Medrxiv

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["MedrxivClusteringP2P"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - MedrxivClusteringP2P, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Dataset 'MedrxivClusteringP2P' is superseeded by 'MedrxivClusteringP2P.v2', you might consider using the newer version of the dataset.
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 37500
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 37500
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClustering called
# <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
# Clustering:   0%|          | 0/10 [00:00<?, ?it/s]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  10%|█         | 1/10 [00:02<00:23,  2.63s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  20%|██        | 2/10 [00:05<00:21,  2.69s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  30%|███       | 3/10 [00:08<00:19,  2.74s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  40%|████      | 4/10 [00:10<00:16,  2.77s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  50%|█████     | 5/10 [00:13<00:14,  2.81s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  60%|██████    | 6/10 [00:15<00:09,  2.40s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  70%|███████   | 7/10 [00:17<00:06,  2.13s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  80%|████████  | 8/10 [00:18<00:03,  1.92s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  90%|█████████ | 9/10 [00:20<00:01,  1.80s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering: 100%|██████████| 10/10 [00:21<00:00,  2.16s/it]

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["MedrxivClusteringP2P.v2"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - MedrxivClusteringP2P.v2, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 37500
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['labels', 'sentences'],
#         num_rows: 37500
#     })
# })
# number of samples: 37500
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClusteringFast called
# len(dataset['sentences']): 37500
# number of samples in downsampled dataset: 1500
# evaluate_clustering_bootstrapped() called
# 10 repetitions of sampling 16384 samples

# %% [markdown]
# #### Reddit

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["RedditClusteringP2P"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - RedditClusteringP2P, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Dataset 'RedditClusteringP2P' is superseeded by 'RedditClusteringP2P.v2', you might consider using the newer version of the dataset.
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 459399
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 459399
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClustering called
# <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
# Clustering:   0%|          | 0/10 [00:00<?, ?it/s]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  10%|█         | 1/10 [00:04<00:39,  4.39s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  20%|██        | 2/10 [00:25<01:51, 13.95s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  30%|███       | 3/10 [00:25<00:55,  7.94s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  40%|████      | 4/10 [00:28<00:34,  5.75s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  50%|█████     | 5/10 [00:52<01:02, 12.51s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  60%|██████    | 6/10 [01:00<00:43, 10.94s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  70%|███████   | 7/10 [01:12<00:33, 11.16s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  80%|████████  | 8/10 [01:27<00:24, 12.47s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  90%|█████████ | 9/10 [01:35<00:10, 11.00s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering: 100%|██████████| 10/10 [01:49<00:00, 10.98s/it]

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["RedditClusteringP2P.v2"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - RedditClusteringP2P.v2, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 459399
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['labels', 'sentences'],
#         num_rows: 459389
#     })
# })
# number of samples: 459389
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClusteringFast called
# len(dataset['sentences']): 459389
# number of samples in downsampled dataset: 18375
# evaluate_clustering_bootstrapped() called
# 10 repetitions of sampling 16384 samples

# %% [markdown]
# #### StackExchange

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["StackExchangeClusteringP2P"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - StackExchangeClusteringP2P, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Dataset 'StackExchangeClusteringP2P' is superseeded by 'StackExchangeClusteringP2P.v2', you might consider using the newer version of the dataset.
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 75000
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 75000
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClustering called
# <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
# Clustering:   0%|          | 0/10 [00:00<?, ?it/s]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  10%|█         | 1/10 [00:03<00:34,  3.81s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  20%|██        | 2/10 [00:07<00:30,  3.79s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  30%|███       | 3/10 [00:11<00:26,  3.75s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  40%|████      | 4/10 [00:14<00:22,  3.73s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  50%|█████     | 5/10 [00:18<00:18,  3.73s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  60%|██████    | 6/10 [00:20<00:12,  3.18s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  70%|███████   | 7/10 [00:22<00:08,  2.83s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  80%|████████  | 8/10 [00:25<00:05,  2.59s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering:  90%|█████████ | 9/10 [00:27<00:02,  2.49s/it]
# cluster set of type <class 'dict'>
# ClusteringEvaluator called
# Clustering: 100%|██████████| 10/10 [00:29<00:00,  2.94s/it]

# %%
evaluation = mteb.MTEB(tasks = mteb.get_tasks(tasks=["StackExchangeClusteringP2P.v2"]))
results = evaluation.run(model, output_folder=results_folder,
                         encode_kwargs = {"ngram_range": (1,1), 
                                          "max_df": 1.0, 
                                          "min_df": 1, 
                                          "max_features": None})
# Out:
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Clustering
#     - StackExchangeClusteringP2P.v2, p2p
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# AbsTask.load_data called
# dataset before transform: DatasetDict({
#     test: Dataset({
#         features: ['sentences', 'labels'],
#         num_rows: 10
#     })
# })
# number of samples: 75000
# dataset after transform: DatasetDict({
#     test: Dataset({
#         features: ['labels', 'sentences'],
#         num_rows: 74914
#     })
# })
# number of samples: 74914
# AbsTask.evaluate called in AbsTask.py
# _evaluate_subset in AbsTaskClusteringFast called
# len(dataset['sentences']): 74914
# number of samples in downsampled dataset: 2996
# evaluate_clustering_bootstrapped() called
# 10 repetitions of sampling 16384 samples
